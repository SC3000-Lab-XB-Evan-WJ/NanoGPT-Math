# %% [markdown]
# ### Step 1: Install necesscary packages

# %%
# !pip install matplotlib
# !pip install torch numpy transformers datasets tiktoken wandb tqdm
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.42.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip3 install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/NanoGPT-Math-1/dpo
# Out:
# /content/drive/MyDrive/NanoGPT-Math-1/dpo

# %% [markdown]
# ### Step 2: Package imports and configuration

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import torch.nn.functional as F
import random
import pickle
from model import GPT, GPTConfig
import random
from tqdm import tqdm
import time
import json
import matplotlib.pyplot as plt
# Configuration
beta = 0.5
if torch.cuda.is_available():
    device = "cuda"
    print("cuda")
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

base_lr = 0.0002
epochs = 30
batch_size = 128
max_length =80
num_samples = 1
max_new_tokens = 200
temperature = 0.8
top_k = 200
# tokenizer
with open("../sft/meta.pkl", "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]
def encode(s): return [stoi[c] for c in s]
def decode(l): return ''.join([itos[i] for i in l])
# Out:
# cuda

# %%
import torch
print(torch.__version__, torch.version.cuda, torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 2.8.0+cu126 12.6 True
# Tesla T4

# %% [markdown]
# ### Step 3: Define helper functions

# %%
def compute_logprob(input_ids):
    inputs = input_ids[:, :-1]
    targets = input_ids[:, 1:]
    logits, _ = gpt(inputs, full_seq=True)
    B, T, V = logits.size()
    logits_flat = logits.reshape(-1, V)
    targets_flat = targets.reshape(-1)
    loss = F.cross_entropy(logits_flat, targets_flat, ignore_index=0, reduction='none')
    loss = loss.reshape(B, T)
    attention_mask = (targets != 0).float()
    loss = (loss * attention_mask).sum(dim=1) / attention_mask.sum(dim=1)
    return -loss

def pad_or_truncate(seq, max_length):
    return seq[:max_length] if len(seq) > max_length else seq + [0] * (max_length - len(seq))

def get_batches(lines, batch_size):
    # random.shuffle(lines)
    #for l in lines:
    #    print(l[1])
    for i in range(0, len(lines), batch_size):
        batch = lines[i:i+batch_size]
        if len(batch) < batch_size:
            continue
        neg_inputs = [pad_or_truncate(encode(p['negative'] + '\n\n\n\n'), max_length) for p in batch]
        pos_inputs = [pad_or_truncate(encode(p['positive'] + '\n\n\n\n'), max_length) for p in batch]
        neg_tensor = torch.tensor(neg_inputs, dtype=torch.long, device=device)
        pos_tensor = torch.tensor(pos_inputs, dtype=torch.long, device=device)
        yield neg_tensor, pos_tensor

# %% [markdown]
# ### Step 4: Load the pretrained NanoGPT model

# %%
ckpt = torch.load("../sft/gpt.pt", map_location=device)
gptconf = GPTConfig(**ckpt['model_args'])
gpt = GPT(gptconf)
state_dict = ckpt['model']
unwanted_prefix = '_orig_mod.'
for k in list(state_dict.keys()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
gpt.to(device).train()
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(74, 348)
#     (wpe): Embedding(256, 348)
#     (drop): Dropout(p=0.2, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x Block(
#         (ln_1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=348, out_features=1044, bias=False)
#           (c_proj): Linear(in_features=348, out_features=348, bias=False)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (resid_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (ln_2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=348, out_features=1392, bias=False)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1392, out_features=348, bias=False)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=348, out_features=74, bias=False)
# )

# %% [markdown]
# ### Step 5: Load Data (**students are required to complete this part!**)

# %%
import random
import json

# Load data
with open('/content/drive/MyDrive/NanoGPT-Math-1/dpo/pos_neg_pairs.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    lines = data

# Augment with negative examples
augmented_lines = []
for item in lines:
    augmented_lines.append(item)
    question = item['positive'].split(' The answer')[0]
    correct_answer = item['positive'].split('equals ')[-1].rstrip('.')

    try:
        left, right = question.split('=')
        if ',' in right:
            right = right.split(',')[0]
        terms = left.replace('-', '+').replace('*', '+').replace('/', '+').split('+')
        nums = []
        var_pos = None
        for i, term in enumerate(terms):
            term = term.strip()
            if term == 'x':
                var_pos = i
            else:
                nums.append(int(term))

        if '+' in left:
            if var_pos is None:  # e.g., "40+61=?"
                a, b = nums
                wrong_answer = str(a + b + 100)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a}+{b} equals {wrong_answer}."
                })
            else:  # e.g., "x+62=151,x=?"
                a, b = (right, nums[0]) if var_pos == 0 else (nums[0], right)
                a, b = int(a), int(b)
                wrong_answer = str(a - b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a} minus {b} equals {wrong_answer}."
                })
        elif '-' in left:
            if var_pos == 0:  # e.g., "x-11=1,x=?"
                a, b = int(right), nums[0]
                wrong_answer = str(a - b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a} minus {b} equals {wrong_answer}."
                })
            else:  # e.g., "72-x=34,x=?"
                a, b = nums[0], int(right)
                wrong_answer = str(a + b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a} plus {b} equals {wrong_answer}."
                })
        elif '*' in left:
            if var_pos is None:  # e.g., "49*7=?"
                a, b = nums
                wrong_answer = str(a + b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a}*{b} equals {wrong_answer}."
                })
            else:  # e.g., "x*11=44,x=?"
                a, b = (nums[0], int(right)) if var_pos == 1 else (int(right), nums[0])
                wrong_answer = str(a + b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a}*{b} equals {wrong_answer}."
                })
        elif '/' in left:
            if var_pos is None:  # e.g., "64/4=?"
                a, b = nums
                wrong_answer = str(a * b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a} divided by {b} equals {wrong_answer}."
                })
            else:  # e.g., "x/7=9,x=?"
                a, b = (int(right), nums[0]) if var_pos == 0 else (nums[0], int(right))
                wrong_answer = str(a // b)
                augmented_lines.append({
                    "positive": item['positive'],
                    "negative": f"{question} The answer is {wrong_answer} because {a} divided by {b} equals {wrong_answer}."
                })
    except ValueError as e:
        print(f"Skipping augmentation for {question}: {e}")
        continue

# Validate data
for i, item in enumerate(augmented_lines):
    if not isinstance(item, dict) or 'positive' not in item or 'negative' not in item:
        raise ValueError(f"Invalid data at index {i}")
    if not isinstance(item['positive'], str) or not isinstance(item['negative'], str):
        raise ValueError(f"Invalid data type at index {i}")

random.shuffle(augmented_lines)
lines = augmented_lines

print(type(lines))  # <class 'list'>
print(len(lines))   # expect ~111388
print(lines[0])     # random item
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping augmentation for x-8=54, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=59, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+62=118, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+78=147, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+22=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32-x=25, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 8+x=25, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+83=109, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+96=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 49-12=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x/26=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-7=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-55=37, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 66-x=26, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+77=175, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74-62=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-0=53, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-x=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 5*x=230, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 20+x=65, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26+x=49, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48+x=140, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 41+x=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 51+x=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+73=101, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+19=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 56+x=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 63-x=17, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-19=58, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+22=88, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80-x=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 88-3=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 31-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 38-x=18, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87+x=127, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84+x=179, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+100=193, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96+x=104, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 3*x=153, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 62-x=20, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86+x=170, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+35=114, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-71=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70+x=143, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+37=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 51-47=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 6+x=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72-20=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 18+x=53, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84+x=135, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+79=170, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78/x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-25=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 71-x=55, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 45+x=143, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 100+x=196, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 55-48=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+85=142, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 33+x=35, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 58+x=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 5+x=35, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 40+x=72, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-x=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 58+x=105, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-26=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 15+x=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 43+x=116, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 60-21=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 33+x=63, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93+x=115, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-32=29, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+54=118, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+59=148, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 71*x=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-12=49, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93+x=121, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19+x=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+11=111, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+72=106, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-40=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 92-x=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32-x=13, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+2=16, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 88+x=148, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74+x=153, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*6=510, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+95=154, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 49-29=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 92-x=76, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+35=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 28+x=52, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+64=138, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 5+x=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80+x=146, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91+x=139, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+18=100, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+71=169, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-76=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 70+x=110, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 54+x=56, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 44+x=121, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96-x=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85+x=155, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+75=75, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 0+x=98, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+35=106, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 95+x=108, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-5=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+4=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 8+x=76, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+29=116, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-18=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 45+x=116, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 71-x=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19-x=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97/x=97, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 6-1=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+12=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-6=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78-6=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 97-67=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 88-x=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87-x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+51=124, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 66-50=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 52-x=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 59-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 87-x=13, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+75=172, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90-27=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 31+x=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 44+x=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 22+x=88, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 54-11=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 53+x=144, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+57=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 65-x=58, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+4=45, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82+x=86, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 99-x=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+40=125, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-x=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+17=43, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+42=87, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 4+x=18, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-16=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x/1=12, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-x=82, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-55=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 95-x=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+77=112, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*7=189, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+99=166, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73*x=584, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 8+x=69, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 39-x=26, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 40/x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=103, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 52+x=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32+x=126, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+96=129, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26+x=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 40-x=17, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74/x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-x=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+92=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+8=15, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86+x=160, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+86=178, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 63-x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+86=161, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70+x=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 49-45=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 13+x=111, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 67+x=109, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 15+x=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70-62=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-51=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 95-69=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 32+x=33, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+35=59, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+55=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74+x=174, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+1=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+92=95, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+93=182, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 6*x=384, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70-x=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 5*x=95, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 76-0=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-0=17, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 53-x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=121, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-x=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+18=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 20+x=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 13+x=14, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 14-12=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-15=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/6=4, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32+x=60, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86-x=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 42-3=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-45=18, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 99-31=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 91-x=65, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+97=175, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 25+x=102, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-43=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 71-5=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 40+x=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72+x=151, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-40=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 77-15=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+3=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+0=72, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-51=34, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 50-10=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-38=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 69-x=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+56=60, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+65=145, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-91=5, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-27=35, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+60=101, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 30+x=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-4=53, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93+x=124, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-54=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+87=139, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-0=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 64+x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 60-x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-13=69, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+86=123, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 25-8=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 74-x=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 61-x=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 75-x=50, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-31=31, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+24=114, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 41+x=62, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 57+x=98, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90-x=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87-25=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 27-24=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 74-x=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+51=107, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-6=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x*29=174, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78+x=118, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 56-x=23, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 69-x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+2=101, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 56+x=124, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*94=282, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+0=93, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+73=104, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 54-26=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 14+x=82, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+51=143, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+74=164, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 68+x=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78-67=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 56+x=96, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 63-x=51, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 1+x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-14=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+24=54, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=176, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+3=52, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+55=140, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*4=240, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-74=19, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85+x=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/9=4, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 14+x=43, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+26=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=24, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19-x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80-21=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-80=15, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 28+x=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 94/x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=104, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 14+x=95, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=112, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-x=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 65-41=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 19+x=63, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 1+x=89, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-7=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+52=55, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 99-86=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 41+x=107, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 71-x=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+66=115, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+53=151, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 52-x=27, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-22=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 33+x=58, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*1=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+3=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-85=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+79=129, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+51=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 38-x=12, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78+x=109, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 9+x=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+99=179, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+61=112, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*3=204, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 18-x=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+58=144, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-18=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-7=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+7=75, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-x=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 2+x=86, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-18=27, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-16=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+0=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 89-x=34, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-48=4, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 81+x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48-x=33, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+20=101, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 77-57=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 67+x=103, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+32=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-9=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-14=15, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-18=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+74=132, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 88-x=19, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 43-x=27, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 39-10=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 48/x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*72=216, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-24=75, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-30=41, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 58-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+65=165, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-39=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*4=324, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90-80=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 43-31=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+89=156, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+56=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-8=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+35=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 88-77=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+58=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-62=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93-x=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-45=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*31=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-33=11, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 15+x=58, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+23=102, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 56-1=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 98-x=8, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 40*x=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/40=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+94=171, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-75=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-3=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+68=165, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80-x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-67=23, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26-15=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-27=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-37=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x*64=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96+x=162, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72-x=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+84=151, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 75+x=93, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=59, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-43=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-20=80, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-x=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-22=26, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 14-6=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 63-32=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 85-5=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 72+x=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-86=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+55=133, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-20=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 35-22=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 33+x=87, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+43=117, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86-x=26, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 2+x=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+57=126, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+56=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*80=720, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 28+x=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+14=93, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93-35=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 71+x=104, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+24=103, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-1=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-5=17, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=43, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+42=76, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*64=192, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=115, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48-16=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+60=156, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+22=110, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 34+x=133, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 34+x=34, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-25=55, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+77=157, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78-x=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+76=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-59=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 11+x=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+100=163, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87-x=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=110, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+64=143, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 81-29=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 15-x=11, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 100-85=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 47+x=78, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 99-36=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+83=152, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90-44=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+2=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/1=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-x=35, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 18+x=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+36=131, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 54-54=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 21-2=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 38+x=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+42=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 36-1=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 35-x=20, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-32=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 22-x=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+54=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+67=96, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 34+x=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+21=98, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19+x=93, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+38=100, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+2=8, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-6=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93-62=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+96=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+30=60, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 69*x=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-38=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78+x=142, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+71=157, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+94=181, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 57+x=147, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86-1=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-6=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+5=48, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+43=142, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+40=140, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-57=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+16=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-35=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72-44=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+36=122, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*62=124, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+66=68, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90/x=90, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-14=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-45=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 50-43=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 2/x=2, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+61=130, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72+x=82, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+0=28, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78+x=139, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+33=100, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 18+x=37, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-x=73, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=52, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 13/x=13, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 10+x=63, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-0=86, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 47-x=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-38=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+23=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*3=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 57+x=107, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87+x=116, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 52+x=147, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=105, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24/x=12, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*45=45, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+79=89, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-9=90, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-56=8, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+14=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82+x=139, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24+x=93, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+72=86, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-x=37, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-66=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+12=16, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*92=184, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-x=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48+x=75, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+96=114, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+68=137, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/33=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73-35=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 74/x=74, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+92=97, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 100-x=15, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-77=11, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26+x=87, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 68+x=157, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+67=162, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 76-x=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 57-31=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 70-49=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 73-x=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-27=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-82=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 60-27=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 25-22=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+91=168, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-70=19, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 49+x=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-20=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+17=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 83-79=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+47=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+25=114, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+89=174, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+47=86, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-26=14, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*42=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70+x=161, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19+x=110, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 67+x=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-21=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 24-x=14, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 31+x=39, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-56=24, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 31+x=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+67=155, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+47=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-22=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 69+x=153, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 8-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 39+x=104, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-95=4, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+81=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+36=71, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 2*x=72, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 92-x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-10=44, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 38+x=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 62-x=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+65=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 75+x=149, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+67=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32-x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 2*x=194, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-2=13, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-57=9, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*69=69, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-39=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x/4=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+13=98, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 39-x=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+99=136, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26+x=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=62, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 83+x=125, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-42=35, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+98=155, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+51=88, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+87=130, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96-61=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+15=113, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*97=776, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 53-32=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 74-x=14, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 23+x=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 63-x=18, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 60+x=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73-x=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-22=68, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82+x=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82-x=52, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+8=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80-31=?: invalid literal for int() with base 10: '?'
# ...
# Skipping augmentation for x-22=56, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 77-x=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-45=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-8=16, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-28=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 32+x=123, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-23=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+30=51, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 94-59=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+9=67, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 53+x=132, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 75+x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+77=109, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73/x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 27-x=21, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+6=47, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+75=87, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96-x=56, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 76-55=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 75-x=56, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82-x=19, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70*x=280, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 58+x=144, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-24=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+90=138, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-12=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 81+x=163, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 34-25=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 99+x=188, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+82=147, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-31=68, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 16*x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 44+x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*45=270, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 28+x=97, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 70-x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+69=164, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 38+x=49, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48/x=12, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+38=67, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 13+x=83, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 78+x=94, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-6=38, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 68+x=151, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*2=72, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+61=147, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 27-8=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 7*x=49, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+93=125, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90/x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74-59=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-0=57, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+32=108, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-48=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+44=52, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-22=51, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 32+x=108, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 54-22=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 89*x=534, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+2=76, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-x=37, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-x=40, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82+x=140, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 17-11=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+67=119, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+84=90, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98+x=119, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-9=77, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*7=63, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 26*x=78, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+83=168, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 47-x=34, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 51-x=1, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 42-x=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+10=101, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+28=111, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+47=110, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-16=23, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 42+x=77, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+45=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-10=30, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+58=106, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 55-x=43, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 1*x=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 23-7=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-14=61, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*87=348, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73+x=144, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+93=169, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 90-77=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 5+x=34, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 19+x=60, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+94=194, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 61+x=111, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-0=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*100=100, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+48=134, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74+x=167, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 33*x=33, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 48+x=108, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-45=42, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+98=137, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 58+x=131, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-42=54, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 85-78=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+71=84, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 77-x=31, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+63=158, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-55=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+77=118, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96+x=109, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82/x=82, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 97-56=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 5*x=130, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*98=784, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+83=99, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 64-x=49, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-5=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+31=123, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 45-x=27, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-32=53, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72+x=106, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+59=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 31-11=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 68-x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91+x=175, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 44-24=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-36=45, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-11=46, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-27=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80-x=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93-x=64, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 23-x=18, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 83-43=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 88+x=114, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+72=103, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 29-23=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 98+x=127, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-1=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+72=130, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 80+x=81, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 94+x=128, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 100-5=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 50+x=55, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 8*x=120, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 96-78=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x-30=70, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 63-x=31, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 68-54=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 93+x=191, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+95=123, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-1=66, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-16=60, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 73+x=79, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+72=162, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 42+x=76, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+59=144, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+67=127, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 69-x=6, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 50/x=10, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-34=16, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 20+x=43, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+8=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+88=122, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 82+x=102, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*40=280, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87-81=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+77=78, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+0=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+73=121, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 71-x=45, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 22-9=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 66/x=33, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 86*x=430, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 72/x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 87+x=88, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-11=15, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 35+x=92, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 91-59=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 72+x=119, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 41+x=129, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 61-x=32, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-56=36, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 64-x=20, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 74-55=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 70+x=163, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-21=27, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x+57=132, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 99-96=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 90-32=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for 50+x=98, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-7=22, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 55+x=143, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 98-x=3, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 77-x=68, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 84-x=7, x=?: too many values to unpack (expected 2)
# Skipping augmentation for 93-56=?: invalid literal for int() with base 10: '?'
# Skipping augmentation for x+85=85, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x*21=0, x=?: too many values to unpack (expected 2)
# Skipping augmentation for x-79=5, x=?: too many values to unpack (expected 2)
# <class 'list'>
# 65863
# {'positive': '42+4=? The answer is 46 because 42+4 equals 46.', 'negative': '42+4=? The answer is 146 because 42+4 equals 146.'}

# %% [markdown]
# ### Step 6: Build the optimizer and scheduler (**students are required to complete this part!**)

# %%
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, LambdaLR

def build_optimizer_and_scheduler(
    model,
    lr=1e-6,
    weight_decay=0.05,
    betas=(0.9, 0.95),
    eps=1e-8,
    total_steps=0,
    warmup_steps=200,
):
    decay, no_decay = [], []
    for name, p in model.named_parameters():
        if not p.requires_grad:
            continue
        if p.ndim >= 2:
            decay.append(p)
        else:
            no_decay.append(p)

    optim_groups = [
        {"params": decay, "weight_decay": weight_decay},
        {"params": no_decay, "weight_decay": 0.0},
    ]

    optimizer = AdamW(optim_groups, lr=lr, betas=betas, eps=1e-8)
    warmup = LambdaLR(optimizer, lr_lambda=lambda step: min(1.0, step / warmup_steps))
    cosine = CosineAnnealingLR(optimizer, T_max=total_steps - warmup_steps, eta_min=1e-7)

    def scheduler_step(step):
        if step < warmup_steps:
            warmup.step()
        else:
            cosine.step()

    return optimizer, scheduler_step

total_steps = (len(lines) // batch_size) * 7  # For 7 epochs
optimizer, scheduler_step = build_optimizer_and_scheduler(
    gpt,
    lr=1e-6,
    weight_decay=0.05,
    betas=(0.9, 0.95),
    eps=1e-8,
    total_steps=total_steps,
    warmup_steps=200,
)

# %% [markdown]
# ### Step 7: Begin training (**students are required to complete this part!**)

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm

def stable_generate(model, input_ids, max_new_tokens, temperature=0.0, top_k=None):
    model.eval()
    generated = input_ids.clone()
    for _ in range(max_new_tokens):
        with torch.no_grad():
            outputs = model(generated)
            logits = outputs[0] if isinstance(outputs, tuple) else outputs
            logits = torch.clamp(logits, min=-1e9, max=1e9)
            if temperature == 0.0:
                next_token = torch.argmax(logits, dim=-1, keepdim=True)  # [batch_size, 1, 1]
                next_token = next_token.squeeze(-1)  # Fix: Squeeze to [batch_size, 1]
            else:
                probs = torch.softmax(logits / temperature, dim=-1)
                if top_k is not None:
                    values, indices = torch.topk(probs, k=top_k, dim=-1)
                    probs = torch.zeros_like(probs).scatter_(-1, indices, values)
                    probs = probs / probs.sum(dim=-1, keepdim=True)
                next_token = torch.multinomial(probs, num_samples=1)  # [batch_size, 1]
            generated = torch.cat([generated, next_token], dim=1)
            if torch.isnan(generated).any() or torch.isinf(generated).any():
                print("NaN/Inf in generated tokens")
                break
    return generated

def compute_logprob(tensor):
    outputs = gpt(tensor)
    logits = outputs[0] if isinstance(outputs, tuple) else outputs
    logits = torch.clamp(logits, min=-1e9, max=1e9)
    return torch.log_softmax(logits, dim=-1)

def validate_model(model, val_set, device):
    model.eval()
    correct = 0
    with torch.no_grad():
        for prompt, expected in val_set:
            prompt_ids = encode(prompt)
            x = torch.tensor([prompt_ids], dtype=torch.long, device=device)
            y = stable_generate(model, x, max_new_tokens=50, temperature=0.0, top_k=None)
            out_full = decode(y[0].cpu().flatten().tolist())
            generated = out_full[len(prompt):].strip()
            if generated.startswith(f"The answer is {expected}"):
                early += 1
    return correct / len(val_set)

# Validation set
val_set = [
    ("17+19=?", "36"),
    ("3*17=?", "51"),
    ("72/4=?", "18"),
    ("72-x=34,x=?", "38"),
    ("x*11=44,x=?", "4"),
    ("2x+5=15,x=?", "5")
]

total_steps = (len(lines) // batch_size) * 7
beta = 0.1
label_smoothing = 0.1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

best_val_acc = 0
best_ckpt_path = "./dpo_best.pt"

for epoch in range(30):
    pbar = tqdm(get_batches(lines, batch_size))
    for step, (neg_tensor, pos_tensor) in enumerate(pbar):
        pos_logprob = compute_logprob(pos_tensor.to(device))
        neg_logprob = compute_logprob(neg_tensor.to(device))

        if torch.isnan(pos_logprob).any() or torch.isinf(pos_logprob).any() or \
           torch.isnan(neg_logprob).any() or torch.isinf(neg_logprob).any():
            print(f"NaN/Inf in logprobs at step {step}, epoch {epoch}")
            continue

        loss = -F.logsigmoid((pos_logprob - neg_logprob) / beta).mean()

        if torch.isnan(loss) or torch.isinf(loss):
            print(f"Invalid loss at step {step}, epoch {epoch}")
            continue

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(gpt.parameters(), max_norm=1.0)

        if (step + 1) % 100 == 0:
            pbar.set_postfix(loss=float(loss.item()), lr=optimizer.param_groups[0]['lr'], grad_norm=float(grad_norm))

        optimizer.step()
        scheduler_step(step)

        if (step + 1) % 200 == 0:
            val_acc = validate_model(gpt, val_set, device)
            print(f"Epoch {epoch}, Step {step}, Validation Accuracy: {val_acc:.2%}")
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                torch.save({
                    "model_state_dict": gpt.state_dict(),
                    "model_args": gptconf.__dict__,
                }, best_ckpt_path)
                print(f"Saved best checkpoint to {best_ckpt_path}")
            if val_acc >= 0.8:  # Stop if 80% accuracy
                print(f"Early stopping at step {step}, epoch {epoch}, val_acc={val_acc:.2%}")
                break

        if loss.item() < 0.003:
            print(f"Early stopping at step {step}, epoch {epoch}, loss={loss.item()}")
            break

    if loss.item() < 0.003 or val_acc >= 0.8:
        break

    ckpt_path = "./dpo.pt"
    for name, param in gpt.named_parameters():
        if torch.isnan(param).any() or torch.isinf(param).any():
            raise ValueError(f"NaN/Inf in model weights: {name}")
    torch.save({
        "model_state_dict": gpt.state_dict(),
        "model_args": gptconf.__dict__,
    }, ckpt_path)
    print(f"Saved checkpoint to {ckpt_path}")
# Out:
# 200it [01:16,  1.41it/s, grad_norm=15.3, loss=1.05, lr=9.95e-7]
# Epoch 0, Step 199, Validation Accuracy: 0.00%
# 400it [02:33,  1.41it/s, grad_norm=2.51, loss=0.081, lr=9.92e-7]
# Epoch 0, Step 399, Validation Accuracy: 0.00%
# 514it [03:17,  2.60it/s, grad_norm=1.78, loss=0.038, lr=9.83e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.803, loss=0.0143, lr=1e-6]
# Epoch 1, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.61it/s, grad_norm=0.0931, loss=0.0109, lr=9.68e-7]
# Epoch 1, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.493, loss=0.0174, lr=9.47e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.0468, loss=0.00999, lr=1e-6]
# Epoch 2, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.41it/s, grad_norm=0.044, loss=0.01, lr=9.44e-7]
# Epoch 2, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.491, loss=0.0166, lr=9.11e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.57it/s, grad_norm=0.0319, loss=0.00972, lr=1e-6]
# Epoch 3, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.57it/s, grad_norm=0.151, loss=0.00993, lr=9.17e-7]
# Epoch 3, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.58it/s, grad_norm=0.349, loss=0.0156, lr=8.72e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.61it/s, grad_norm=0.0502, loss=0.00966, lr=1e-6]
# Epoch 4, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.64it/s, grad_norm=2.72, loss=0.0111, lr=8.88e-7]
# Epoch 4, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.149, loss=0.0152, lr=8.29e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.0483, loss=0.0096, lr=1e-6]
# Epoch 5, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=1.63, loss=0.0103, lr=8.52e-7]
# Epoch 5, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0708, loss=0.015, lr=7.78e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.49it/s, grad_norm=0.0469, loss=0.00956, lr=1e-6]
# Epoch 6, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.51it/s, grad_norm=1.82, loss=0.0103, lr=8.08e-7]
# Epoch 6, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.049, loss=0.015, lr=7.15e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.59it/s, grad_norm=0.0467, loss=0.00954, lr=1e-6]
# Epoch 7, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.42it/s, grad_norm=1.32, loss=0.01, lr=7.46e-7]
# Epoch 7, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.0527, loss=0.0149, lr=6.31e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.40it/s, grad_norm=0.0471, loss=0.00953, lr=1e-6]
# Epoch 8, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.41it/s, grad_norm=2.02, loss=0.0102, lr=6.53e-7]
# Epoch 8, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.123, loss=0.015, lr=5.08e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.048, loss=0.00953, lr=1e-6]
# Epoch 9, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.63it/s, grad_norm=2.47, loss=0.0102, lr=4.88e-7]
# Epoch 9, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.296, loss=0.0151, lr=3.09e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.64it/s, grad_norm=0.0438, loss=0.00951, lr=1e-6]
# Epoch 10, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=1.09, loss=0.00985, lr=1.47e-7]
# Epoch 10, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.547, loss=0.0152, lr=1e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.41it/s, grad_norm=0.039, loss=0.0095, lr=1e-6]
# Epoch 11, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.48it/s, grad_norm=0.308, loss=0.0104, lr=1.87e-5]
# Epoch 11, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=5, loss=0.0431, lr=3.6e-5]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.00467, loss=0.00945, lr=1e-6]
# Epoch 12, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.44it/s, grad_norm=0.00784, loss=0.00947, lr=2.2e-6]
# Epoch 12, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.0238, loss=0.0148, lr=2.98e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.0089, loss=0.00943, lr=1e-6]
# Epoch 13, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.64it/s, grad_norm=0.0172, loss=0.0095, lr=1.57e-6]
# Epoch 13, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0167, loss=0.0148, lr=1.89e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.45it/s, grad_norm=0.00895, loss=0.00943, lr=1e-6]
# Epoch 14, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.43it/s, grad_norm=0.025, loss=0.00954, lr=1.35e-6]
# Epoch 14, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.0267, loss=0.0148, lr=1.55e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.63it/s, grad_norm=0.00926, loss=0.00942, lr=1e-6]
# Epoch 15, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.61it/s, grad_norm=0.0209, loss=0.00952, lr=1.25e-6]
# Epoch 15, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0551, loss=0.0149, lr=1.37e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.00893, loss=0.00942, lr=1e-6]
# Epoch 16, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.64it/s, grad_norm=0.017, loss=0.0095, lr=1.18e-6]
# Epoch 16, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0813, loss=0.0149, lr=1.27e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.63it/s, grad_norm=0.00865, loss=0.00942, lr=1e-6]
# Epoch 17, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=0.0148, loss=0.00948, lr=1.13e-6]
# Epoch 17, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0878, loss=0.0149, lr=1.19e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.61it/s, grad_norm=0.00786, loss=0.00941, lr=1e-6]
# Epoch 18, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.64it/s, grad_norm=0.0151, loss=0.00948, lr=1.09e-6]
# Epoch 18, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0945, loss=0.0149, lr=1.13e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.51it/s, grad_norm=0.00676, loss=0.00941, lr=1e-6]
# Epoch 19, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.49it/s, grad_norm=0.0752, loss=0.00949, lr=1.06e-6]
# Epoch 19, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.179, loss=0.015, lr=1.08e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.63it/s, grad_norm=0.00601, loss=0.00941, lr=1e-6]
# Epoch 20, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=0.104, loss=0.00949, lr=1.03e-6]
# Epoch 20, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.303, loss=0.0151, lr=1.04e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.00536, loss=0.0094, lr=1e-6]
# Epoch 21, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.63it/s, grad_norm=0.0149, loss=0.00945, lr=1.01e-6]
# Epoch 21, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.343, loss=0.0151, lr=1.01e-6]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.44it/s, grad_norm=0.00467, loss=0.0094, lr=1e-6]
# Epoch 22, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.48it/s, grad_norm=0.024, loss=0.00944, lr=9.84e-7]
# Epoch 22, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.402, loss=0.0152, lr=9.7e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.63it/s, grad_norm=0.00398, loss=0.00939, lr=1e-6]
# Epoch 23, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=0.401, loss=0.00954, lr=9.6e-7]
# Epoch 23, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.33, loss=0.0151, lr=9.35e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.00336, loss=0.00939, lr=1e-6]
# Epoch 24, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.63it/s, grad_norm=0.031, loss=0.00943, lr=9.35e-7]
# Epoch 24, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.34, loss=0.0151, lr=8.98e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.41it/s, grad_norm=0.00283, loss=0.00939, lr=1e-6]
# Epoch 25, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.44it/s, grad_norm=0.0191, loss=0.00942, lr=9.07e-7]
# Epoch 25, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.242, loss=0.015, lr=8.58e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.62it/s, grad_norm=0.00251, loss=0.00938, lr=1e-6]
# Epoch 26, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.63it/s, grad_norm=0.0139, loss=0.00941, lr=8.76e-7]
# Epoch 26, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.258, loss=0.015, lr=8.12e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.65it/s, grad_norm=0.00221, loss=0.00938, lr=1e-6]
# Epoch 27, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.63it/s, grad_norm=0.0115, loss=0.00941, lr=8.38e-7]
# Epoch 27, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.167, loss=0.0149, lr=7.58e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.45it/s, grad_norm=0.00182, loss=0.00938, lr=1e-6]
# Epoch 28, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.43it/s, grad_norm=0.0101, loss=0.0094, lr=7.88e-7]
# Epoch 28, Step 399, Validation Accuracy: 0.00%
# 514it [03:19,  2.58it/s, grad_norm=0.126, loss=0.0148, lr=6.88e-7]
# Saved checkpoint to ./dpo.pt
# 200it [01:17,  1.63it/s, grad_norm=0.00148, loss=0.00938, lr=1e-6]
# Epoch 29, Step 199, Validation Accuracy: 0.00%
# 400it [02:35,  1.62it/s, grad_norm=0.00898, loss=0.00939, lr=7.18e-7]
# Epoch 29, Step 399, Validation Accuracy: 0.00%
# 514it [03:18,  2.59it/s, grad_norm=0.0816, loss=0.0148, lr=5.93e-7]
# Saved checkpoint to ./dpo.pt

# %% [markdown]
# # Step 8: Begin testing (**students are required to complete this part!**)

# %%
import torch
import os
import numpy as np

os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
os.environ['TORCH_USE_CUDA_DSA'] = '1'

def stable_generate(model, input_ids, max_new_tokens, temperature=0.0, top_k=None):
    model.eval()
    generated = input_ids.clone()
    for _ in range(max_new_tokens):
        with torch.no_grad():
            outputs = model(generated)
            logits = outputs[0] if isinstance(outputs, tuple) else outputs
            logits = torch.clamp(logits, min=-1e9, max=1e9)
            if temperature == 0.0:
                next_token = torch.argmax(logits, dim=-1, keepdim=True)  # [batch_size, 1, 1]
                next_token = next_token.squeeze(-1)  # Fix: Squeeze to [batch_size, 1]
            else:
                probs = torch.softmax(logits / temperature, dim=-1)
                if top_k is not None:
                    values, indices = torch.topk(probs, k=top_k, dim=-1)
                    probs = torch.zeros_like(probs).scatter_(-1, indices, values)
                    probs = probs / probs.sum(dim=-1, keepdim=True)
                next_token = torch.multinomial(probs, num_samples=1)  # [batch_size, 1]
            generated = torch.cat([generated, next_token], dim=1)
            if torch.isnan(generated).any() or torch.isinf(generated).any():
                print("NaN/Inf in generated tokens")
                break
    return generated

ckpt_path = "./dpo_best.pt"
try:
    checkpoint = torch.load(ckpt_path, map_location='cpu')
    print("Checkpoint keys:", checkpoint.keys())

    gptconf = GPTConfig(**checkpoint['model_args'])
    gpt = GPT(gptconf)

    state_dict = checkpoint['model_state_dict']
    for k, v in state_dict.items():
        if torch.isnan(v).any() or torch.isinf(v).any():
            raise ValueError(f"NaN/Inf in state_dict key: {k}")

    cleaned_state_dict = {k[len('_orig_mod.'):]: v if k.startswith('_orig_mod.') else k: v for k, v in state_dict.items()}
    gpt.load_state_dict(cleaned_state_dict, strict=False)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    try:
        gpt = gpt.to(device)
        print(f"Model moved to {device}")
    except RuntimeError as e:
        print(f"Failed to move to CUDA: {e}")
        device = torch.device('cpu')
        gpt = gpt.to(device)

    gpt.eval()
    test_set = ["17+19=?", "3*17=?", "72/4=?", "72-x=34,x=?", "x*11=44,x=?",
                "3*17=?", "72/4=?", "72-x=34,x=?", "x-15=27,x=?",
                "95+x=142,x=?", "x/7=9,x=?", "3x=24,x=?", "x+4=18,x=?",
                "x-7=23,x=?", "2x+5=15,x=?"]

    with torch.no_grad():
        for prompt in test_set:
            prompt_ids = encode(prompt)
            x = torch.tensor([prompt_ids], dtype=torch.long, device=device)

            y = stable_generate(
                gpt,
                x,
                max_new_tokens=50,
                temperature=0.0,
                top_k=None
            )
            out_full = decode(y[0].cpu().flatten().tolist())
            generated = out_full[len(prompt):].strip()

            print(f"Q: {prompt}")
            print(f"A: {generated}\n")
except Exception as e:
    print(f"Error in testing: {e}")
    print("Debugging tips: Rerun Step 7, check encode/decode, or verify CUDA setup.")
# Out:
#   File "/tmp/ipython-input-165416435.py", line 45
#     cleaned_state_dict = {k[len('_orig_mod.'):]: v if k.startswith('_orig_mod.') else k: v for k, v in state_dict.items()}
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
# Load the fine-tuned model
ckpt_path = "../dpo/dpo.pt"
checkpoint = torch.load(ckpt_path, map_location=device)
gptconf = GPTConfig(**checkpoint['model_args'])
gpt = GPT(gptconf).to(device)
try:
    state_dict = checkpoint['model']
except:
    state_dict = checkpoint['model_state_dict']
unwanted_prefix = '_orig_mod.'
for k,v in list(state_dict.items()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
gpt.load_state_dict(state_dict)
# Test
gpt.eval()
test_set = ["17+19=?", "3*17=?", "72/4=?", "72-x=34,x=?", "x*11=44,x=?", "3*17=?", "72/4=?", "72-x=34,x=?"]
test_set += ["x-15=27,x=?", "95+x=142,x=?", "x/7=9,x=?", "3x=24,x=?", "x+4=18,x=?", "x-7=23,x=?", "2x+5=15,x=?"]

with torch.no_grad():
    for prompt in test_set:
        prompt_ids = encode(prompt)
        ###########################################################
        # Please complete the test code here!
        # ...
        # gpt.generate(x, max_new_tokens, temperature=temperature, top_k=top_k)
        # ...
        x = torch.tensor([prompt_ids], dtype=torch.long, device=device)  # shape [1, T]

        y = gpt.generate(
            x,
            max_new_tokens=max_new_tokens,      # you defined these above
            temperature=temperature,
            top_k=top_k
        )
        out_full = decode(y[0].cpu().flatten().tolist())
        generated = out_full[len(prompt):].strip()

        print(f"Q: {prompt}")
        print(f"A: {generated}\n")
        ###########################################################
# Out:
# Q: 17+19=?
# A: Sory, I don't know.
#
# Q: 3*17=?
# A: Sory, I don't know.
#
# Q: 72/4=?
# A: Sory, I don't know.
#
# Q: 72-x=34,x=?
# A: Sory, I don't know.
#
# Q: x*11=44,x=?
# A: Sory, I don't know.
#
# Q: 3*17=?
# A: Sory, I don't know.
#
# Q: 72/4=?
# A: Sory, I don't know.
#
# Q: 72-x=34,x=?
# A: Sory, I don't know.
#
# Q: x-15=27,x=?
# A: Sory, I don't know.
#
# Q: 95+x=142,x=?
# A: Sory, I don't know.
#
# Q: x/7=9,x=?
# A: I don't know.
#
# Q: 3x=24,x=?
# A: I don't know.
#
# Q: x+4=18,x=?
# A: Sory, I don't know.
#
# Q: x-7=23,x=?
# A: Sory, I don't know.
#
# Q: 2x+5=15,x=?
# A: Sory, I don't know.
